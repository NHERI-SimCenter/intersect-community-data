# %% [markdown]
# # Housing Unit Inventory for 2020
#
# ## Overview
# This code tests out the new table structures for the 2020 Decennial Census.

# %% [markdown]
# ## Description of Program
# - program:    ncoda_07gv1_HUI_2020
# - task:       test 2020 Census Housing Unit Inventory
# - See github commits for description of program updates
# - Current Version: 2025-02-21
# - project:    pyncoda
# - funding:	  Southeast Texas Urban Integrated Field Lab DE-SC0023216
# - author:     Nathanael Rosenheim
#
# ## Required Citations:
# Rosenheim, Nathanael, Roberto Guidotti, Paolo Gardoni & Walter Gillis Peacock. (2021). Integration of detailed household and housing unit characteristic data with critical infrastructure for post-hazard resilience modeling. _Sustainable and Resilient Infrastructure_. 6(6), 385-401. https://doi.org/10.1080/23789689.2019.1681821
#
# Rosenheim, Nathanael (2021) “Detailed Household and Housing Unit Characteristics: Data and Replication Code.” _DesignSafe-CI_.
# https://doi.org/10.17603/ds2-jwf6-s535.

# %%
# To reload submodules need to use this magic command to set autoreload on
# %load_ext autoreload
# %autoreload 2
from pyncoda.ncoda_00g_community_options import *
from IPython.display import display

# %% [markdown]
# ### How to set up the Community Dictionary
# Please review the python code in the file pyncoda/ncoda_00g_community_options.py
#
# In this file you will find a collection of data dictionaries with various ways to setup the inputs for the Housing Unit Allocation process.
#
# The basic dictionary includes the name of the community, the county FIPS code, your input building inventory file, and key variables in the building inventory file.

# %%
# select a community from this list
# if your community is not in this list, add it to the file ncoda_00g_community_options.py
list_community_options(communities_dictionary)
# Out:
# ['Lumberton, NC: IN-CORE Building inventory for Robeson County, NC',
#  'Galveston, TX: IN-CORE Building inventory for Galveston County, TX',
#  'Galveston, TX: NSI Building inventory for Galveston County, TX',
#  'Galveston, TX: IN-CORE Building inventory for Galveston Island, TX',
#  'Mayfield, KY: NSI Building inventory for Graves County, KY',
#  'Beaumont, TX: NSI Building inventory for Jefferson County, TX',
#  'Beaumont, TX: Safayet Building inventory for Jefferson County, TX',
#  'Pentwater, MI: NSI Building inventory for Oceana County, MI',
#  'Seaside, OR: NSI Building inventory for Clatsop County, OR',
#  'Lane County, OR: NSI Building inventory for Lane County, OR',
#  'Benton County, OR: NSI Building inventory for Benton County, OR',
#  'Southeast Texas Urban Integrated Field Lab: NSI Building inventory for Southeast Texas',
#  'Southeast Texas Urban Integrated Field Lab (12 neighbor counties): NSI Building inventory for Southeast Texas',
#  'Brazos County, TX: NSI Building inventory for Brazos County, TX',
#  'Adams Co, CO: NSI Building inventory for Adams County, CO, 2010',
#  'Broomfield Co, CO: NSI Building inventory for Broomfield County, CO, 2010']

# %%
community_id_by_name = 'Seaside, OR: NSI Building inventory for Clatsop County, OR'

# %%
community_id, focalplace, countyname, countyfips = get_community_id_by_name(community_id_by_name)
communities = {community_id : communities_dictionary[community_id]}
# Out:
# Selected community ID: Seaside_OR_NSI
# Seaside, OR is in OREGON
# Focal place: Seaside
# Seaside, OR is in Clatsop County, OR with FIPS code 41007
# Use IN-CORE: False

# %% [markdown]
# ## Setup Python Environment

# %%
import pandas as pd
import geopandas as gpd # For reading in shapefiles
import numpy as np
import sys # For displaying package versions
import os # For managing directories and file paths if drive is mounted
import scooby # Reports Python environment

import contextily as cx # For adding basemap tiles to plot
import matplotlib.pyplot as plt # For plotting and making graphs

# %%
# open, read, and execute python program with reusable commands
from pyncoda.ncoda_00d_cleanvarsutils import *
from pyncoda.ncoda_04c_poptableresults import *
from pyncoda.ncoda_07i_process_communities import process_community_workflow

# %%
# Generate report of Python environment
base_packages = ['pandas','ipyleaflet','seaborn','contextily']
incore_packages = ['pyincore','pyincore_viz']
check_packages = base_packages + incore_packages
print(scooby.Report(additional=check_packages))
# Out:
# --------------------------------------------------------------------------------
#   Date: Wed Sep 17 11:01:47 2025 Central Daylight Time
#
#                 OS : Windows (10 10.0.22631 SP0 Multiprocessor Free)
#             CPU(s) : 16
#            Machine : AMD64
#       Architecture : 64bit
#                RAM : 31.7 GiB
#        Environment : Jupyter
#
#   Python 3.10.14 | packaged by Anaconda, Inc. | (main, May  6 2024, 19:44:50)
#   [MSC v.1916 64 bit (AMD64)]
#
#             pandas : 2.2.2
#         ipyleaflet : Module not found
#            seaborn : 0.13.2
#         contextily : 1.6.0
#           pyincore : Module not found
#       pyincore_viz : Module not found
#              numpy : 1.26.4
#              scipy : 1.13.1
#            IPython : 8.25.0
#         matplotlib : 3.8.4
#             scooby : 0.10.0
#
#   Intel(R) oneAPI Math Kernel Library Version 2023.1-Product Build 20230303
#   for Intel(R) 64 architecture applications
# --------------------------------------------------------------------------------

# %%
# Check working directory - good practice for relative path access
os.getcwd()
# Out:
# 'c:\\Users\\nathanael99\\MyProjects\\GitHub\\intersect-community-data'

# %% [markdown]
# ## Run Base Housing Unit Inventory for 2020

# %%
# open, read, and execute python program with reusable commands
from pyncoda.ncoda_00b_directory_design import directory_design
from pyncoda.CommunitySourceData.api_census_gov.acg_01a_BaseInventory import BaseInventory

seed = 9876
version = '2.0.0'
version_text = 'v2-0-0'
basevintage = 2010
outputfolder ="OutputData"
outputfolders = {}
savefiles = True
use_incore = False

# %%
mutually_exclusive_varstems_roots_dictionary_lists = {}
new_char_dictionaries = {}
new_char_dictionaries['family'] = {}
new_char_dictionaries['Hispanic'] = {}

# %%
from pyncoda.CommunitySourceData.api_census_gov.acg_00b_hui_block2010 import *
from pyncoda.CommunitySourceData.api_census_gov.acg_00c_hispan_block2010 import *

mutually_exclusive_varstems_roots_dictionary_lists[2010] = [tenure_size_H16_varstem_roots,
                                                    vacancy_status_H5_varstem_roots,
                                                    group_quarters_P42_varstem_roots]

new_char_dictionaries['family'][2010] = [family_byrace_P18_varstem_roots]
new_char_dictionaries['Hispanic'][2010] = [tenure_size_H16HAI_varstem_roots,
                                        hispan_byrace_H7_varstem_roots,
                                        tenure_byhispan_H15_varstem_roots
                                        ]

# %%
# updated for 2020
from pyncoda.CommunitySourceData.api_census_gov.acg_00b_hui_block2020 import *
from pyncoda.CommunitySourceData.api_census_gov.acg_00c_hispan_block2020 import *

mutually_exclusive_varstems_roots_dictionary_lists[2020] = [tenure_size_H12_2020_varstem_roots,
                                                    vacancy_status_H5_2020_varstem_roots,
                                                    group_quarters_P18_2020_varstem_roots]

new_char_dictionaries['family'][2020] = [family_byrace_P16_2020_varstem_roots]
new_char_dictionaries['Hispanic'][2020] = [tenure_size_H12HAI_2020_varstem_roots,
                                        hispan_byrace_H7_2020_varstem_roots,
                                        tenure_byhispan_H11_2020_varstem_roots
                                        ]

# %%
vintage = 2010
for community in communities.keys():

    # Create empty container to store outputs for in-core
    # Will use these to combine multiple counties
    hui_incore_county_df = {}
    title = "Housing Unit Inventory v2.0.0 data for "+communities[community]['community_name']
    print("Generating",title)
    output_filename = f'hui_{version_text}_{community}_{basevintage}_rs{seed}'

    county_list = ''

    # set output folder
    outputfolders = directory_design(
                        state_county_name = community,
                        outputfolder = outputfolder)

    # community dictionary
    community_dict = communities[community]
    use_incore = community_dict['building_inventory']['use_incore']


    # Workflow for generating HUI data for IN-CORE
    for county in communities[community]['counties'].keys():
        state_county = communities[community]['counties'][county]['FIPS Code']
        state_county_name  = communities[community]['counties'][county]['Name']
        print(state_county_name,': county FIPS Code',state_county)
        county_list = county_list + state_county_name+': county FIPS Code '+state_county

        print("Generating HUI data for",state_county_name)

        # create output folders for hui data generation
        outputfolders = directory_design(state_county_name = community,
                                            outputfolder = outputfolder)
                          
        # Generate base housing unit inventory
        block_df = {}
        block_df['core'] = BaseInventory.get_apidata(state_county = state_county, 
                                                    geo_level = 'Block',
                                                    vintage = str(vintage),
                                                    mutually_exclusive_varstems_roots_dictionaries =
                                                                        mutually_exclusive_varstems_roots_dictionary_lists[vintage],
                                                    outputfolders = outputfolders,
                                                    outputfile = "CoreHUI")
        
        block_df['family'] = BaseInventory.graft_on_new_char(base_inventory= block_df['core'],
                                                            state_county = state_county,
                                                            new_char = 'family',
                                                            new_char_dictionaries = new_char_dictionaries['family'][vintage],
                                                            basevintage = str(vintage), 
                                                            basegeolevel = 'Block',
                                                            outputfile = "hui",
                                                            outputfolders = outputfolders)

       
        block_df['hispan'] = BaseInventory.graft_on_new_char(base_inventory= block_df['family'],
                                                        state_county = state_county,
                                                        new_char = 'hispan',
                                                        new_char_dictionaries = new_char_dictionaries['Hispanic'][vintage],
                                                        basevintage = str(vintage), 
                                                        basegeolevel = 'Block',
                                                        outputfile = "hui",
                                                        outputfolders = outputfolders)
# Out:
# Generating Housing Unit Inventory v2.0.0 data for Seaside, OR
# Clatsop County, OR : county FIPS Code 41007
# Generating HUI data for Clatsop County, OR
# File OutputData/Seaside_OR_NSI/03_BaseInventory/CoreHUI_41007_2010.csv Already exists - Skipping API Call.
# File OutputData/Seaside_OR_NSI/03_BaseInventory/hui_family_41007_2010.csv Already exists with new variable grafted - Skipping API Call.
# File OutputData/Seaside_OR_NSI/03_BaseInventory/hui_hispan_41007_2010.csv Already exists with new variable grafted - Skipping API Call.

# %%
block_df['core'].head()
# Out:
#                    huid        Block2010      Block2010str  numprec  ownershp  \
# 0  B410079501001001H001  410079501001001  B410079501001001      1.0       1.0
# 1  B410079501001001H002  410079501001001  B410079501001001      2.0       1.0
# 2  B410079501001001H003  410079501001001  B410079501001001      2.0       2.0
# 3  B410079501001003H001  410079501001003  B410079501001003      1.0       2.0
# 4  B410079501001003H002  410079501001003  B410079501001003      1.0       2.0
#
#    family  race  hispan  vacancy  gqtype  hu_counter
# 0     0.0   1.0     0.0      NaN     NaN           1
# 1  -999.0   1.0     0.0      NaN     NaN           2
# 2  -999.0   1.0     0.0      NaN     NaN           3
# 3     0.0   1.0     0.0      NaN     NaN           1
# 4     0.0   1.0     0.0      NaN     NaN           2

# %%
block_df['family'].head()
# Out:
#                    huid        Block2010      Block2010str  numprec  ownershp  \
# 0  B410079501001001H001  410079501001001  B410079501001001      1.0       1.0
# 1  B410079501001003H001  410079501001003  B410079501001003      1.0       2.0
# 2  B410079501001003H002  410079501001003  B410079501001003      1.0       2.0
# 3  B410079501001004H001  410079501001004  B410079501001004      1.0       2.0
# 4  B410079501001004H002  410079501001004  B410079501001004      1.0       2.0
#
#    family  race  hispan  vacancy  gqtype  hu_counter  \
# 0     0.0   1.0     0.0      NaN     NaN         1.0
# 1     0.0   1.0     0.0      NaN     NaN         1.0
# 2     0.0   1.0     0.0      NaN     NaN         2.0
# 3     0.0   1.0     0.0      NaN     NaN         1.0
# 4     0.0   1.0     0.0      NaN     NaN         2.0
#
#                    family_flag  family_flagset  totalprob_family  familybyP18  \
# 0  family set to 0 by core hui             1.0               0.0          NaN
# 1  family set to 0 by core hui             1.0               0.0          NaN
# 2  family set to 0 by core hui             1.0               0.0          NaN
# 3  family set to 0 by core hui             1.0               0.0          NaN
# 4  family set to 0 by core hui             1.0               0.0          NaN
#
#    hucount_familybyP18  sumby_familybyP18  prob_familybyP18  \
# 0                  NaN                NaN               NaN
# 1                  NaN                NaN               NaN
# 2                  NaN                NaN               NaN
# 3                  NaN                NaN               NaN
# 4                  NaN                NaN               NaN
#
#    familybyP18_counter  hucount_familybyP18updated
# 0                  NaN                         NaN
# 1                  NaN                         NaN
# 2                  NaN                         NaN
# 3                  NaN                         NaN
# 4                  NaN                         NaN

# %%
block_df['hispan'].head()
# Out:
#                    huid        Block2010      Block2010str  numprec  ownershp  \
# 0  B410079501001001H001  410079501001001  B410079501001001      1.0       1.0
# 1  B410079501001003H001  410079501001003  B410079501001003      1.0       2.0
# 2  B410079501001003H002  410079501001003  B410079501001003      1.0       2.0
# 3  B410079501001004H001  410079501001004  B410079501001004      1.0       2.0
# 4  B410079501001004H002  410079501001004  B410079501001004      1.0       2.0
#
#    family  race  hispan  vacancy  gqtype  ...  hispanbyH015  \
# 0     0.0   1.0     0.0      NaN     NaN  ...           NaN
# 1     0.0   1.0     0.0      NaN     NaN  ...           NaN
# 2     0.0   1.0     0.0      NaN     NaN  ...           NaN
# 3     0.0   1.0     0.0      NaN     NaN  ...           NaN
# 4     0.0   1.0     0.0      NaN     NaN  ...           NaN
#
#   hucount_hispanbyH015  sumby_hispanbyH015  prob_hispanbyH015  \
# 0                  NaN                 NaN                NaN
# 1                  NaN                 NaN                NaN
# 2                  NaN                 NaN                NaN
# 3                  NaN                 NaN                NaN
# 4                  NaN                 NaN                NaN
#
#    hispanbyH16HAI_counter  hispanbyH007_counter  hispanbyH015_counter  \
# 0                     NaN                   NaN                   NaN
# 1                     NaN                   NaN                   NaN
# 2                     NaN                   NaN                   NaN
# 3                     NaN                   NaN                   NaN
# 4                     NaN                   NaN                   NaN
#
#    hucount_hispanbyH16HAIupdated  hucount_hispanbyH007updated  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#    hucount_hispanbyH015updated
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
# [5 rows x 41 columns]

# %%
from pyncoda.ncoda_04c_poptableresults import *
# add race ethnicity to data frame for better map legends
hui_race_df = PopResultsTable.add_race_ethnicity_to_pop_df(block_df['hispan'])

# %%
hui_race_df.head()
# Out:
#                    huid        Block2010      Block2010str  numprec  ownershp  \
# 0  B410079501001001H001  410079501001001  B410079501001001      1.0       1.0
# 1  B410079501001003H001  410079501001003  B410079501001003      1.0       2.0
# 2  B410079501001003H002  410079501001003  B410079501001003      1.0       2.0
# 3  B410079501001004H001  410079501001004  B410079501001004      1.0       2.0
# 4  B410079501001004H002  410079501001004  B410079501001004      1.0       2.0
#
#    family  race  hispan  vacancy  gqtype  ...  hucount_hispanbyH015  \
# 0     0.0   1.0     0.0      NaN     NaN  ...                   NaN
# 1     0.0   1.0     0.0      NaN     NaN  ...                   NaN
# 2     0.0   1.0     0.0      NaN     NaN  ...                   NaN
# 3     0.0   1.0     0.0      NaN     NaN  ...                   NaN
# 4     0.0   1.0     0.0      NaN     NaN  ...                   NaN
#
#   sumby_hispanbyH015  prob_hispanbyH015  hispanbyH16HAI_counter  \
# 0                NaN                NaN                     NaN
# 1                NaN                NaN                     NaN
# 2                NaN                NaN                     NaN
# 3                NaN                NaN                     NaN
# 4                NaN                NaN                     NaN
#
#    hispanbyH007_counter  hispanbyH015_counter  hucount_hispanbyH16HAIupdated  \
# 0                   NaN                   NaN                            NaN
# 1                   NaN                   NaN                            NaN
# 2                   NaN                   NaN                            NaN
# 3                   NaN                   NaN                            NaN
# 4                   NaN                   NaN                            NaN
#
#    hucount_hispanbyH007updated  hucount_hispanbyH015updated  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#                 Race Ethnicity
# 0  1 White alone, Not Hispanic
# 1  1 White alone, Not Hispanic
# 2  1 White alone, Not Hispanic
# 3  1 White alone, Not Hispanic
# 4  1 White alone, Not Hispanic
#
# [5 rows x 42 columns]

# %%
where = communities[community_id]['community_name']
print(where, focalplace, countyname, countyfips)
# Out:
# Seaside, OR Seaside Clatsop County, OR 41007

# %%
PopResultsTable.pop_results_table(
                  input_df = hui_race_df, 
                  who = "Total Population by Households", 
                  what = "by Race, Ethnicity",
                  where = countyname,
                  when = "2020",
                  row_index = "Race Ethnicity",
                  col_index = 'Tenure Status')
# Out:
# <style type="text/css">
# #T_bd18e caption {
#   text-align: center;
#   caption-side: top;
#   font-size: 150%;
# }
# </style>
# <table id="T_bd18e">
#   <caption>Table. Total Population by Households by Race, Ethnicity, Clatsop County, OR, 2020.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Tenure Status</th>
#       <th id="T_bd18e_level0_col0" class="col_heading level0 col0" >1 Owner Occupied (%)</th>
#       <th id="T_bd18e_level0_col1" class="col_heading level0 col1" >2 Renter Occupied (%)</th>
#       <th id="T_bd18e_level0_col2" class="col_heading level0 col2" >Total Population by Households (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Race Ethnicity</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd18e_level0_row0" class="row_heading level0 row0" >1 White alone, Not Hispanic</th>
#       <td id="T_bd18e_row0_col0" class="data row0 col0" >21,017	 (93.7%)</td>
#       <td id="T_bd18e_row0_col1" class="data row0 col1" >11,027	 (81.6%)</td>
#       <td id="T_bd18e_row0_col2" class="data row0 col2" >32,044	 (89.2%)</td>
#     </tr>
#     <tr>
#       <th id="T_bd18e_level0_row1" class="row_heading level0 row1" >2 Black alone, Not Hispanic</th>
#       <td id="T_bd18e_row1_col0" class="data row1 col0" >55	 (0.2%)</td>
#       <td id="T_bd18e_row1_col1" class="data row1 col1" >42	 (0.3%)</td>
#       <td id="T_bd18e_row1_col2" class="data row1 col2" >97	 (0.3%)</td>
#     </tr>
#     <tr>
#       <th id="T_bd18e_level0_row2" class="row_heading level0 row2" >3 American Indian and Alaska Native alone, Not Hispanic</th>
#       <td id="T_bd18e_row2_col0" class="data row2 col0" >136	 (0.6%)</td>
#       <td id="T_bd18e_row2_col1" class="data row2 col1" >149	 (1.1%)</td>
#       <td id="T_bd18e_row2_col2" class="data row2 col2" >285	 (0.8%)</td>
#     </tr>
#     <tr>
#       <th id="T_bd18e_level0_row3" class="row_heading level0 row3" >4 Asian alone, Not Hispanic</th>
#       <td id="T_bd18e_row3_col0" class="data row3 col0" >248	 (1.1%)</td>
#       <td id="T_bd18e_row3_col1" class="data row3 col1" >92	 (0.7%)</td>
#       <td id="T_bd18e_row3_col2" class="data row3 col2" >340	 (0.9%)</td>
#     </tr>
#     <tr>
#       <th id="T_bd18e_level0_row4" class="row_heading level0 row4" >5 Other Race, Not Hispanic</th>
#       <td id="T_bd18e_row4_col0" class="data row4 col0" >369	 (1.6%)</td>
#       <td id="T_bd18e_row4_col1" class="data row4 col1" >424	 (3.1%)</td>
#       <td id="T_bd18e_row4_col2" class="data row4 col2" >793	 (2.2%)</td>
#     </tr>
#     <tr>
#       <th id="T_bd18e_level0_row5" class="row_heading level0 row5" >6 Any Race, Hispanic</th>
#       <td id="T_bd18e_row5_col0" class="data row5 col0" >607	 (2.7%)</td>
#       <td id="T_bd18e_row5_col1" class="data row5 col1" >1,772	 (13.1%)</td>
#       <td id="T_bd18e_row5_col2" class="data row5 col2" >2,379	 (6.6%)</td>
#     </tr>
#     <tr>
#       <th id="T_bd18e_level0_row6" class="row_heading level0 row6" >Total</th>
#       <td id="T_bd18e_row6_col0" class="data row6 col0" >22,432	 (100.0%)</td>
#       <td id="T_bd18e_row6_col1" class="data row6 col1" >13,506	 (100.0%)</td>
#       <td id="T_bd18e_row6_col2" class="data row6 col2" >35,938	 (100.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
block_df['core']['gqtype'].value_counts()
# Out:
# gqtype
# 7.0    26
# 3.0     3
# 1.0     1
# 6.0     1
# 2.0     1
# 5.0     1
# Name: count, dtype: int64

# %%
# fill in missing values for group quarters with 0
block_df['core']['gqtype'] = block_df['core']['gqtype'].fillna(0)
# make an integer
block_df['core']['gqtype'] = block_df['core']['gqtype'].astype(int)
block_df['core']['gqtype'].value_counts()
# Out:
# gqtype
# 0    21546
# 7       26
# 3        3
# 1        1
# 6        1
# 2        1
# 5        1
# Name: count, dtype: int64

# %%
block_df['family']['gqtype'].value_counts()
# Out:
# gqtype
# 7.0    26
# 3.0     3
# 1.0     1
# 6.0     1
# 2.0     1
# 5.0     1
# Name: count, dtype: int64

# %%
block_df['hispan']['gqtype'].value_counts()
# Out:
# gqtype
# 7.0    26
# 3.0     3
# 1.0     1
# 6.0     1
# 2.0     1
# 5.0     1
# Name: count, dtype: int64

# %%
block_df['core']['All'] = 'All'

PopResultsTable.pop_results_table(
                  input_df = block_df['core'], 
                  who = "Total Population by Households", 
                  what = "by Group Quarters Type",
                  where = countyname,
                  when = f"{vintage}",
                  row_index = 'Group Quarters Type',
                  col_index = 'All')
# Out:
# <style type="text/css">
# #T_d97ab caption {
#   text-align: center;
#   caption-side: top;
#   font-size: 150%;
# }
# </style>
# <table id="T_d97ab">
#   <caption>Table. Total Population by Households by Group Quarters Type, Clatsop County, OR, 2010.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >All</th>
#       <th id="T_d97ab_level0_col0" class="col_heading level0 col0" >All (%)</th>
#       <th id="T_d97ab_level0_col1" class="col_heading level0 col1" >Total Population by Households (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Group Quarters Type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d97ab_level0_row0" class="row_heading level0 row0" >0. NA (non-group quarters)</th>
#       <td id="T_d97ab_row0_col0" class="data row0 col0" >35,938	 (97.4%)</td>
#       <td id="T_d97ab_row0_col1" class="data row0 col1" >35,938	 (97.4%)</td>
#     </tr>
#     <tr>
#       <th id="T_d97ab_level0_row1" class="row_heading level0 row1" >1. Correctional facilities for adults</th>
#       <td id="T_d97ab_row1_col0" class="data row1 col0" >68	 (0.2%)</td>
#       <td id="T_d97ab_row1_col1" class="data row1 col1" >68	 (0.2%)</td>
#     </tr>
#     <tr>
#       <th id="T_d97ab_level0_row2" class="row_heading level0 row2" >2. Juvenile facilities</th>
#       <td id="T_d97ab_row2_col0" class="data row2 col0" >50	 (0.1%)</td>
#       <td id="T_d97ab_row2_col1" class="data row2 col1" >50	 (0.1%)</td>
#     </tr>
#     <tr>
#       <th id="T_d97ab_level0_row3" class="row_heading level0 row3" >3. Nursing facilities/Skilled-nursing facilities</th>
#       <td id="T_d97ab_row3_col0" class="data row3 col0" >78	 (0.2%)</td>
#       <td id="T_d97ab_row3_col1" class="data row3 col1" >78	 (0.2%)</td>
#     </tr>
#     <tr>
#       <th id="T_d97ab_level0_row4" class="row_heading level0 row4" >5. College/University student housing</th>
#       <td id="T_d97ab_row4_col0" class="data row4 col0" >117	 (0.3%)</td>
#       <td id="T_d97ab_row4_col1" class="data row4 col1" >117	 (0.3%)</td>
#     </tr>
#     <tr>
#       <th id="T_d97ab_level0_row5" class="row_heading level0 row5" >6. Military quarters</th>
#       <td id="T_d97ab_row5_col0" class="data row5 col0" >127	 (0.3%)</td>
#       <td id="T_d97ab_row5_col1" class="data row5 col1" >127	 (0.3%)</td>
#     </tr>
#     <tr>
#       <th id="T_d97ab_level0_row6" class="row_heading level0 row6" >7. Other noninstitutional facilities</th>
#       <td id="T_d97ab_row6_col0" class="data row6 col0" >516	 (1.4%)</td>
#       <td id="T_d97ab_row6_col1" class="data row6 col1" >516	 (1.4%)</td>
#     </tr>
#     <tr>
#       <th id="T_d97ab_level0_row7" class="row_heading level0 row7" >Total</th>
#       <td id="T_d97ab_row7_col0" class="data row7 col0" >36,894	 (100.0%)</td>
#       <td id="T_d97ab_row7_col1" class="data row7 col1" >36,894	 (100.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
hui_race_df['All'] = 'All'

PopResultsTable.pop_results_table(
                  input_df = hui_race_df, 
                  who = "Total Population by Households", 
                  what = "by Group Quarters Type",
                  where = countyname,
                  when = f"{vintage}",
                  row_index = 'Group Quarters Type',
                  col_index = 'All')
# Out:
# <style type="text/css">
# #T_48c13 caption {
#   text-align: center;
#   caption-side: top;
#   font-size: 150%;
# }
# </style>
# <table id="T_48c13">
#   <caption>Table. Total Population by Households by Group Quarters Type, Clatsop County, OR, 2010.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >All</th>
#       <th id="T_48c13_level0_col0" class="col_heading level0 col0" >All (%)</th>
#       <th id="T_48c13_level0_col1" class="col_heading level0 col1" >Total Population by Households (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Group Quarters Type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48c13_level0_row0" class="row_heading level0 row0" >1. Correctional facilities for adults</th>
#       <td id="T_48c13_row0_col0" class="data row0 col0" >68	 (7.1%)</td>
#       <td id="T_48c13_row0_col1" class="data row0 col1" >68	 (7.1%)</td>
#     </tr>
#     <tr>
#       <th id="T_48c13_level0_row1" class="row_heading level0 row1" >2. Juvenile facilities</th>
#       <td id="T_48c13_row1_col0" class="data row1 col0" >50	 (5.2%)</td>
#       <td id="T_48c13_row1_col1" class="data row1 col1" >50	 (5.2%)</td>
#     </tr>
#     <tr>
#       <th id="T_48c13_level0_row2" class="row_heading level0 row2" >3. Nursing facilities/Skilled-nursing facilities</th>
#       <td id="T_48c13_row2_col0" class="data row2 col0" >78	 (8.2%)</td>
#       <td id="T_48c13_row2_col1" class="data row2 col1" >78	 (8.2%)</td>
#     </tr>
#     <tr>
#       <th id="T_48c13_level0_row3" class="row_heading level0 row3" >5. College/University student housing</th>
#       <td id="T_48c13_row3_col0" class="data row3 col0" >117	 (12.2%)</td>
#       <td id="T_48c13_row3_col1" class="data row3 col1" >117	 (12.2%)</td>
#     </tr>
#     <tr>
#       <th id="T_48c13_level0_row4" class="row_heading level0 row4" >6. Military quarters</th>
#       <td id="T_48c13_row4_col0" class="data row4 col0" >127	 (13.3%)</td>
#       <td id="T_48c13_row4_col1" class="data row4 col1" >127	 (13.3%)</td>
#     </tr>
#     <tr>
#       <th id="T_48c13_level0_row5" class="row_heading level0 row5" >7. Other noninstitutional facilities</th>
#       <td id="T_48c13_row5_col0" class="data row5 col0" >516	 (54.0%)</td>
#       <td id="T_48c13_row5_col1" class="data row5 col1" >516	 (54.0%)</td>
#     </tr>
#     <tr>
#       <th id="T_48c13_level0_row6" class="row_heading level0 row6" >Total</th>
#       <td id="T_48c13_row6_col0" class="data row6 col0" >956	 (100.0%)</td>
#       <td id="T_48c13_row6_col1" class="data row6 col1" >956	 (100.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
# list if HUID = B410079502001025H099
block_df['core'][[f'Block{vintage}','huid','gqtype']][block_df['core'][f'Block{vintage}'] == '410079502001025']
# Out:
#              Block2010                  huid  gqtype
# 1571   410079502001025  B410079502001025H001       0
# 1572   410079502001025  B410079502001025H002       0
# 1573   410079502001025  B410079502001025H003       0
# 1574   410079502001025  B410079502001025H004       0
# 1575   410079502001025  B410079502001025H005       0
# ...                ...                   ...     ...
# 1634   410079502001025  B410079502001025H064       0
# 14967  410079502001025  B410079502001025H065       0
# 15456  410079502001025  B410079502001025H066       0
# 15958  410079502001025  B410079502001025H067       0
# 15959  410079502001025  B410079502001025H068       0
#
# [68 rows x 3 columns]

# %%
# list if HUID = B410079502001025H099
block_df['family'][[f'Block{vintage}','huid','gqtype']][block_df['family'][f'Block{vintage}'] == '410079502001025'].sort_values(by = 'huid')
# Out:
#              Block2010                  huid  gqtype
# 511    410079502001025  B410079502001025H001     NaN
# 512    410079502001025  B410079502001025H002     NaN
# 12170  410079502001025  B410079502001025H003     NaN
# 513    410079502001025  B410079502001025H004     NaN
# 514    410079502001025  B410079502001025H005     NaN
# ...                ...                   ...     ...
# 12174  410079502001025  B410079502001025H064     NaN
# 4789   410079502001025  B410079502001025H065     NaN
# 4879   410079502001025  B410079502001025H066     NaN
# 5179   410079502001025  B410079502001025H067     NaN
# 5180   410079502001025  B410079502001025H068     NaN
#
# [68 rows x 3 columns]

# %%
# list if HUID = B410079502001025H099
block_df['hispan'][[f'Block{vintage}','huid','gqtype']][block_df['hispan'][f'Block{vintage}'] == '410079502001025'].sort_values(by = 'huid')
# Out:
#              Block2010                  huid  gqtype
# 511    410079502001025  B410079502001025H001     NaN
# 512    410079502001025  B410079502001025H002     NaN
# 11807  410079502001025  B410079502001025H003     NaN
# 513    410079502001025  B410079502001025H004     NaN
# 514    410079502001025  B410079502001025H005     NaN
# ...                ...                   ...     ...
# 11811  410079502001025  B410079502001025H064     NaN
# 20708  410079502001025  B410079502001025H065     NaN
# 20709  410079502001025  B410079502001025H066     NaN
# 4936   410079502001025  B410079502001025H067     NaN
# 4937   410079502001025  B410079502001025H068     NaN
#
# [68 rows x 3 columns]

# %%
# describe the variable gqtype
hui_race_df['gqtype'].value_counts()
# Out:
# gqtype
# 7.0    26
# 3.0     3
# 1.0     1
# 6.0     1
# 2.0     1
# 5.0     1
# Name: count, dtype: int64

# %%
# describe the variable vacancy
hui_race_df['vacancy'].value_counts()
# Out:
# vacancy
# 5.0    4298
# 1.0     611
# 7.0     440
# 3.0     360
# 4.0      47
# 2.0      44
# 6.0       4
# Name: count, dtype: int64

# %%
hui_race_df = PopResultsTable.add_vacancy_to_pop_df(hui_race_df)

PopResultsTable.pop_results_table(
                  input_df = hui_race_df, 
                  who = "Total Households", 
                  what = "by Vacancy Type",
                  where = countyname,
                  when = f'{vintage}',
                  row_index = 'Vacancy Type',
                  col_index = 'All')
# Out:
# <style type="text/css">
# #T_b9002 caption {
#   text-align: center;
#   caption-side: top;
#   font-size: 150%;
# }
# </style>
# <table id="T_b9002">
#   <caption>Table. Total Households by Vacancy Type, Clatsop County, OR, 2010.</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >All</th>
#       <th id="T_b9002_level0_col0" class="col_heading level0 col0" >All (%)</th>
#       <th id="T_b9002_level0_col1" class="col_heading level0 col1" >Total Households (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Vacancy Type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9002_level0_row0" class="row_heading level0 row0" >1 For Rent</th>
#       <td id="T_b9002_row0_col0" class="data row0 col0" >611	 (10.5%)</td>
#       <td id="T_b9002_row0_col1" class="data row0 col1" >611	 (10.5%)</td>
#     </tr>
#     <tr>
#       <th id="T_b9002_level0_row1" class="row_heading level0 row1" >2 Rented, not occupied</th>
#       <td id="T_b9002_row1_col0" class="data row1 col0" >44	 (0.8%)</td>
#       <td id="T_b9002_row1_col1" class="data row1 col1" >44	 (0.8%)</td>
#     </tr>
#     <tr>
#       <th id="T_b9002_level0_row2" class="row_heading level0 row2" >3 For sale only</th>
#       <td id="T_b9002_row2_col0" class="data row2 col0" >360	 (6.2%)</td>
#       <td id="T_b9002_row2_col1" class="data row2 col1" >360	 (6.2%)</td>
#     </tr>
#     <tr>
#       <th id="T_b9002_level0_row3" class="row_heading level0 row3" >4 Sold, not occupied</th>
#       <td id="T_b9002_row3_col0" class="data row3 col0" >47	 (0.8%)</td>
#       <td id="T_b9002_row3_col1" class="data row3 col1" >47	 (0.8%)</td>
#     </tr>
#     <tr>
#       <th id="T_b9002_level0_row4" class="row_heading level0 row4" >5 For seasonal, recreational, or occasional use</th>
#       <td id="T_b9002_row4_col0" class="data row4 col0" >4,298	 (74.1%)</td>
#       <td id="T_b9002_row4_col1" class="data row4 col1" >4,298	 (74.1%)</td>
#     </tr>
#     <tr>
#       <th id="T_b9002_level0_row5" class="row_heading level0 row5" >6 For migrant workers</th>
#       <td id="T_b9002_row5_col0" class="data row5 col0" >4	 (0.1%)</td>
#       <td id="T_b9002_row5_col1" class="data row5 col1" >4	 (0.1%)</td>
#     </tr>
#     <tr>
#       <th id="T_b9002_level0_row6" class="row_heading level0 row6" >7 Other vacant</th>
#       <td id="T_b9002_row6_col0" class="data row6 col0" >440	 (7.6%)</td>
#       <td id="T_b9002_row6_col1" class="data row6 col1" >440	 (7.6%)</td>
#     </tr>
#     <tr>
#       <th id="T_b9002_level0_row7" class="row_heading level0 row7" >Total</th>
#       <td id="T_b9002_row7_col0" class="data row7 col0" >5,804	 (100.0%)</td>
#       <td id="T_b9002_row7_col1" class="data row7 col1" >5,804	 (100.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %%
print("Total Population by Race and Ethnicity 2010:")
print(f"https://data.census.gov/cedsci/table?g=050XX00US{countyfips}&tid=DECENNIALSF12010.P5")

print("Total Population by Race and Ethnicity 2020:")
print(f"https://data.census.gov/cedsci/table?g=050XX00US{countyfips}&tid=DECENNIALDHC2020.P5")

print("Total Vacancy Status 2010:")
print(f"https://data.census.gov/cedsci/table?g=050XX00US{countyfips}&tid=DECENNIALSF12010.H5")

print("Total Vacancy Status 2020:")
print(f"https://data.census.gov/cedsci/table?g=050XX00US{countyfips}&tid=DECENNIALDHC2020.H5")
# Out:
# Total Population by Race and Ethnicity 2010:
# https://data.census.gov/cedsci/table?g=050XX00US41007&tid=DECENNIALSF12010.P5
# Total Population by Race and Ethnicity 2020:
# https://data.census.gov/cedsci/table?g=050XX00US41007&tid=DECENNIALDHC2020.P5
# Total Vacancy Status 2010:
# https://data.census.gov/cedsci/table?g=050XX00US41007&tid=DECENNIALSF12010.H5
# Total Vacancy Status 2020:
# https://data.census.gov/cedsci/table?g=050XX00US41007&tid=DECENNIALDHC2020.H5
